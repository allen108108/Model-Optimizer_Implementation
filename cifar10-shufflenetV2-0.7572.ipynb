# %% [markdown]
# ## 作業
# 礙於不是所有同學都有 GPU ，這邊的範例使用的是簡化版本的 ResNet，確保所有同學都能夠順利訓練!
#
#
# 最後一天的作業請閱讀這篇非常詳盡的[文章](https://blog.gtwang.org/programming/keras-resnet-50-pre-trained-model-build-dogs-cats-image-classification-system/)，基本上已經涵蓋了所有訓練　CNN 常用的技巧，請使用所有學過的訓練技巧，盡可能地提高 Cifar-10 的 test data 準確率，截圖你最佳的結果並上傳來完成最後一次的作業吧!
#
# 另外這些技巧在 Kaggle 上也會被許多人使用，更有人會開發一些新的技巧，例如使把預訓練在 ImageNet 上的模型當成 feature extractor 後，再拿擷取出的特徵重新訓練新的模型，這些技巧再進階的課程我們會在提到，有興趣的同學也可以[參考](https://www.kaggle.com/insaff/img-feature-extraction-with-pretrained-resnet)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os,shutil
from sklearn.model_selection import train_test_split
from tensorflow.python.keras.preprocessing.image import ImageDataGenerator
from keras.datasets import mnist
from keras.callbacks import ReduceLROnPlateau
from keras.datasets import cifar10
from keras.utils import to_categorical
from keras import layers
from keras import models
from keras import optimizers

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

x_train,x_val,y_train,y_val=train_test_split(x_train, y_train,test_size=0.25,random_state=13)

# %%
x_train.shape
# Out:
# (37500, 32, 32, 3)

# %%
LR_function=ReduceLROnPlateau(monitor='val_acc',
                             patience=3,
                             verbose=1,
                             factor=0.5,
                             min_lr=0.000001)

# %%
train_datagen = ImageDataGenerator(
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   channel_shift_range=10,
                                   horizontal_flip=True,
                                   fill_mode='nearest')
train_datagen.fit(x_train)                                  

valid_datagen = ImageDataGenerator()
valid_datagen.fit(x_val)

# %%
import os
from keras import backend as K
from keras_applications.imagenet_utils import _obtain_input_shape
from keras.models import Model
from keras.engine.topology import get_source_inputs
from keras.layers import Activation, Add, Concatenate, Conv2D, GlobalMaxPooling2D
from keras.layers import GlobalAveragePooling2D,Input, Dense
from keras.layers import MaxPool2D,AveragePooling2D, BatchNormalization, Lambda, DepthwiseConv2D
import numpy as np


def channel_split(x, name=''):
    # equipartition
    in_channles = x.shape.as_list()[-1]
    ip = in_channles // 2
    c_hat = Lambda(lambda z: z[:, :, :, 0:ip], name='%s/sp%d_slice' % (name, 0))(x)
    c = Lambda(lambda z: z[:, :, :, ip:], name='%s/sp%d_slice' % (name, 1))(x)
    return c_hat, c

def channel_shuffle(x):
    height, width, channels = x.shape.as_list()[1:]
    channels_per_split = channels // 2
    x = K.reshape(x, [-1, height, width, 2, channels_per_split])
    x = K.permute_dimensions(x, (0,1,2,4,3))
    x = K.reshape(x, [-1, height, width, channels])
    return x


def shuffle_unit(inputs, out_channels, bottleneck_ratio,strides=2,stage=1,block=1):
    if K.image_data_format() == 'channels_last':
        bn_axis = -1
    else:
        raise ValueError('Only channels last supported')

    prefix = 'stage{}/block{}'.format(stage, block)
    bottleneck_channels = int(out_channels * bottleneck_ratio)
    if strides < 2:
        c_hat, c = channel_split(inputs, '{}/spl'.format(prefix))
        inputs = c

    x = Conv2D(bottleneck_channels, kernel_size=(1,1), strides=1, padding='same', name='{}/1x1conv_1'.format(prefix))(inputs)
    x = BatchNormalization(axis=bn_axis, name='{}/bn_1x1conv_1'.format(prefix))(x)
    x = Activation('relu', name='{}/relu_1x1conv_1'.format(prefix))(x)
    x = DepthwiseConv2D(kernel_size=3, strides=strides, padding='same', name='{}/3x3dwconv'.format(prefix))(x)
    x = BatchNormalization(axis=bn_axis, name='{}/bn_3x3dwconv'.format(prefix))(x)
    x = Conv2D(bottleneck_channels, kernel_size=1,strides=1,padding='same', name='{}/1x1conv_2'.format(prefix))(x)
    x = BatchNormalization(axis=bn_axis, name='{}/bn_1x1conv_2'.format(prefix))(x)
    x = Activation('relu', name='{}/relu_1x1conv_2'.format(prefix))(x)

    if strides < 2:
        ret = Concatenate(axis=bn_axis, name='{}/concat_1'.format(prefix))([x, c_hat])
    else:
        s2 = DepthwiseConv2D(kernel_size=3, strides=2, padding='same', name='{}/3x3dwconv_2'.format(prefix))(inputs)
        s2 = BatchNormalization(axis=bn_axis, name='{}/bn_3x3dwconv_2'.format(prefix))(s2)
        s2 = Conv2D(bottleneck_channels, kernel_size=1,strides=1,padding='same', name='{}/1x1_conv_3'.format(prefix))(s2)
        s2 = BatchNormalization(axis=bn_axis, name='{}/bn_1x1conv_3'.format(prefix))(s2)
        s2 = Activation('relu', name='{}/relu_1x1conv_3'.format(prefix))(s2)
        ret = Concatenate(axis=bn_axis, name='{}/concat_2'.format(prefix))([x, s2])

    ret = Lambda(channel_shuffle, name='{}/channel_shuffle'.format(prefix))(ret)

    return ret


def block(x, channel_map, bottleneck_ratio, repeat=1, stage=1):
    x = shuffle_unit(x, out_channels=channel_map[stage-1],
                      strides=2,bottleneck_ratio=bottleneck_ratio,stage=stage,block=1)

    for i in range(1, repeat+1):
        x = shuffle_unit(x, out_channels=channel_map[stage-1],strides=1,
                          bottleneck_ratio=bottleneck_ratio,stage=stage, block=(1+i))

    return x

import numpy as np
from keras.utils import plot_model
from keras_applications.imagenet_utils import _obtain_input_shape
from keras.engine.topology import get_source_inputs
from keras.layers import Input, Conv2D, MaxPool2D, GlobalMaxPooling2D, GlobalAveragePooling2D
from keras.layers import Activation, Dense
from keras.models import Model
import keras.backend as K



def ShuffleNetV2(include_top=True,
                 input_tensor=None,
                 scale_factor=1.0,
                 pooling='max',
                 input_shape=(224,224,3),
                 load_model=None,
                 num_shuffle_units=[3,7,3],
                 bottleneck_ratio=1,
                 classes=1000):
    if K.backend() != 'tensorflow':
        raise RuntimeError('Only tensorflow supported for now')
    name = 'ShuffleNetV2_{}_{}_{}'.format(scale_factor, bottleneck_ratio, "".join([str(x) for x in num_shuffle_units]))
    input_shape = _obtain_input_shape(input_shape, default_size=224, min_size=28, require_flatten=include_top,
                                      data_format=K.image_data_format())
    out_dim_stage_two = {0.5:48, 1:116, 1.5:176, 2:244}

    if pooling not in ['max', 'avg']:
        raise ValueError('Invalid value for pooling')
    if not (float(scale_factor)*4).is_integer():
        raise ValueError('Invalid value for scale_factor, should be x over 4')
    exp = np.insert(np.arange(len(num_shuffle_units), dtype=np.float32), 0, 0)  # [0., 0., 1., 2.]
    out_channels_in_stage = 2**exp
    out_channels_in_stage *= out_dim_stage_two[bottleneck_ratio]  #  calculate output channels for each stage
    out_channels_in_stage[0] = 24  # first stage has always 24 output channels
    out_channels_in_stage *= scale_factor
    out_channels_in_stage = out_channels_in_stage.astype(int)

    if input_tensor is None:
        img_input = Input(shape=input_shape)
    else:
        if not K.is_keras_tensor(input_tensor):
            img_input = Input(tensor=input_tensor, shape=input_shape)
        else:
            img_input = input_tensor

    # create shufflenet architecture
    x = Conv2D(filters=out_channels_in_stage[0], kernel_size=(3, 3), padding='same', use_bias=False, strides=(2, 2),
               activation='relu', name='conv1')(img_input)
    x = MaxPool2D(pool_size=(3, 3), strides=(2, 2), padding='same', name='maxpool1')(x)

    # create stages containing shufflenet units beginning at stage 2
    for stage in range(len(num_shuffle_units)):
        repeat = num_shuffle_units[stage]
        x = block(x, out_channels_in_stage,
                   repeat=repeat,
                   bottleneck_ratio=bottleneck_ratio,
                   stage=stage + 2)

    if bottleneck_ratio < 2:
        k = 1024
    else:
        k = 2048
    x = Conv2D(k, kernel_size=1, padding='same', strides=1, name='1x1conv5_out', activation='relu')(x)

    if pooling == 'avg':
        x = GlobalAveragePooling2D(name='global_avg_pool')(x)
    elif pooling == 'max':
        x = GlobalMaxPooling2D(name='global_max_pool')(x)

    if include_top:
        x = Dense(classes, name='fc')(x)
        x = Activation('softmax', name='softmax')(x)

    if input_tensor:
        inputs = get_source_inputs(input_tensor)

    else:
        inputs = img_input

    model = Model(inputs, x, name=name)

    if load_model:
        model.load_weights('', by_name=True)

    return model

if __name__ == '__main__':
    import os
    os.environ['CUDA_VISIBLE_DEVICES'] = ''
    model = ShuffleNetV2(include_top=True, input_shape=(28,28,1), bottleneck_ratio=1)
    plot_model(model, to_file='shufflenetv2.jpg', show_layer_names=True, show_shapes=True)


    pass

# %%
model=ShuffleNetV2(input_shape=(32,32,3),classes=10)


model.summary()
model.compile(optimizer='Adam' , loss='categorical_crossentropy' , metrics=['accuracy'])
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 16, 16, 24)   648         input_4[0][0]
# __________________________________________________________________________________________________
# maxpool1 (MaxPooling2D)         (None, 8, 8, 24)     0           conv1[0][0]
# __________________________________________________________________________________________________
# stage2/block1/1x1conv_1 (Conv2D (None, 8, 8, 116)    2900        maxpool1[0][0]
# __________________________________________________________________________________________________
# stage2/block1/bn_1x1conv_1 (Bat (None, 8, 8, 116)    464         stage2/block1/1x1conv_1[0][0]
# __________________________________________________________________________________________________
# stage2/block1/relu_1x1conv_1 (A (None, 8, 8, 116)    0           stage2/block1/bn_1x1conv_1[0][0]
# __________________________________________________________________________________________________
# stage2/block1/3x3dwconv (Depthw (None, 4, 4, 116)    1160        stage2/block1/relu_1x1conv_1[0][0
# __________________________________________________________________________________________________
# stage2/block1/3x3dwconv_2 (Dept (None, 4, 4, 24)     240         maxpool1[0][0]
# __________________________________________________________________________________________________
# stage2/block1/bn_3x3dwconv (Bat (None, 4, 4, 116)    464         stage2/block1/3x3dwconv[0][0]
# __________________________________________________________________________________________________
# stage2/block1/bn_3x3dwconv_2 (B (None, 4, 4, 24)     96          stage2/block1/3x3dwconv_2[0][0]
# __________________________________________________________________________________________________
# stage2/block1/1x1conv_2 (Conv2D (None, 4, 4, 116)    13572       stage2/block1/bn_3x3dwconv[0][0]
# __________________________________________________________________________________________________
# stage2/block1/1x1_conv_3 (Conv2 (None, 4, 4, 116)    2900        stage2/block1/bn_3x3dwconv_2[0][0
# __________________________________________________________________________________________________
# stage2/block1/bn_1x1conv_2 (Bat (None, 4, 4, 116)    464         stage2/block1/1x1conv_2[0][0]
# __________________________________________________________________________________________________
# stage2/block1/bn_1x1conv_3 (Bat (None, 4, 4, 116)    464         stage2/block1/1x1_conv_3[0][0]
# __________________________________________________________________________________________________
# stage2/block1/relu_1x1conv_2 (A (None, 4, 4, 116)    0           stage2/block1/bn_1x1conv_2[0][0]
# __________________________________________________________________________________________________
# stage2/block1/relu_1x1conv_3 (A (None, 4, 4, 116)    0           stage2/block1/bn_1x1conv_3[0][0]
# __________________________________________________________________________________________________
# stage2/block1/concat_2 (Concate (None, 4, 4, 232)    0           stage2/block1/relu_1x1conv_2[0][0
#                                                                  stage2/block1/relu_1x1conv_3[0][0
# __________________________________________________________________________________________________
# stage2/block1/channel_shuffle ( (None, 4, 4, 232)    0           stage2/block1/concat_2[0][0]
# __________________________________________________________________________________________________
# stage2/block2/spl/sp1_slice (La (None, 4, 4, 116)    0           stage2/block1/channel_shuffle[0][
# __________________________________________________________________________________________________
# stage2/block2/1x1conv_1 (Conv2D (None, 4, 4, 116)    13572       stage2/block2/spl/sp1_slice[0][0]
# __________________________________________________________________________________________________
# stage2/block2/bn_1x1conv_1 (Bat (None, 4, 4, 116)    464         stage2/block2/1x1conv_1[0][0]
# __________________________________________________________________________________________________
# stage2/block2/relu_1x1conv_1 (A (None, 4, 4, 116)    0           stage2/block2/bn_1x1conv_1[0][0]
# __________________________________________________________________________________________________
# stage2/block2/3x3dwconv (Depthw (None, 4, 4, 116)    1160        stage2/block2/relu_1x1conv_1[0][0
# __________________________________________________________________________________________________
# stage2/block2/bn_3x3dwconv (Bat (None, 4, 4, 116)    464         stage2/block2/3x3dwconv[0][0]
# __________________________________________________________________________________________________
# stage2/block2/1x1conv_2 (Conv2D (None, 4, 4, 116)    13572       stage2/block2/bn_3x3dwconv[0][0]
# __________________________________________________________________________________________________
# stage2/block2/bn_1x1conv_2 (Bat (None, 4, 4, 116)    464         stage2/block2/1x1conv_2[0][0]
# __________________________________________________________________________________________________
# stage2/block2/relu_1x1conv_2 (A (None, 4, 4, 116)    0           stage2/block2/bn_1x1conv_2[0][0]
# __________________________________________________________________________________________________
# stage2/block2/spl/sp0_slice (La (None, 4, 4, 116)    0           stage2/block1/channel_shuffle[0][
# __________________________________________________________________________________________________
# stage2/block2/concat_1 (Concate (None, 4, 4, 232)    0           stage2/block2/relu_1x1conv_2[0][0
#                                                                  stage2/block2/spl/sp0_slice[0][0]
# __________________________________________________________________________________________________
# stage2/block2/channel_shuffle ( (None, 4, 4, 232)    0           stage2/block2/concat_1[0][0]
# __________________________________________________________________________________________________
# stage2/block3/spl/sp1_slice (La (None, 4, 4, 116)    0           stage2/block2/channel_shuffle[0][
# __________________________________________________________________________________________________
# stage2/block3/1x1conv_1 (Conv2D (None, 4, 4, 116)    13572       stage2/block3/spl/sp1_slice[0][0]
# __________________________________________________________________________________________________
# stage2/block3/bn_1x1conv_1 (Bat (None, 4, 4, 116)    464         stage2/block3/1x1conv_1[0][0]
# __________________________________________________________________________________________________
# stage2/block3/relu_1x1conv_1 (A (None, 4, 4, 116)    0           stage2/block3/bn_1x1conv_1[0][0]
# __________________________________________________________________________________________________
# stage2/block3/3x3dwconv (Depthw (None, 4, 4, 116)    1160        stage2/block3/relu_1x1conv_1[0][0
# __________________________________________________________________________________________________
# stage2/block3/bn_3x3dwconv (Bat (None, 4, 4, 116)    464         stage2/block3/3x3dwconv[0][0]
# __________________________________________________________________________________________________
# stage2/block3/1x1conv_2 (Conv2D (None, 4, 4, 116)    13572       stage2/block3/bn_3x3dwconv[0][0]
# __________________________________________________________________________________________________
# stage2/block3/bn_1x1conv_2 (Bat (None, 4, 4, 116)    464         stage2/block3/1x1conv_2[0][0]
# __________________________________________________________________________________________________
# stage2/block3/relu_1x1conv_2 (A (None, 4, 4, 116)    0           stage2/block3/bn_1x1conv_2[0][0]
# __________________________________________________________________________________________________
# stage2/block3/spl/sp0_slice (La (None, 4, 4, 116)    0           stage2/block2/channel_shuffle[0][
# __________________________________________________________________________________________________
# stage2/block3/concat_1 (Concate (None, 4, 4, 232)    0           stage2/block3/relu_1x1conv_2[0][0
#                                                                  stage2/block3/spl/sp0_slice[0][0]
# __________________________________________________________________________________________________
# stage2/block3/channel_shuffle ( (None, 4, 4, 232)    0           stage2/block3/concat_1[0][0]
# __________________________________________________________________________________________________
# stage2/block4/spl/sp1_slice (La (None, 4, 4, 116)    0           stage2/block3/channel_shuffle[0][
# __________________________________________________________________________________________________
# stage2/block4/1x1conv_1 (Conv2D (None, 4, 4, 116)    13572       stage2/block4/spl/sp1_slice[0][0]
# __________________________________________________________________________________________________
# stage2/block4/bn_1x1conv_1 (Bat (None, 4, 4, 116)    464         stage2/block4/1x1conv_1[0][0]
# __________________________________________________________________________________________________
# stage2/block4/relu_1x1conv_1 (A (None, 4, 4, 116)    0           stage2/block4/bn_1x1conv_1[0][0]
# __________________________________________________________________________________________________
# stage2/block4/3x3dwconv (Depthw (None, 4, 4, 116)    1160        stage2/block4/relu_1x1conv_1[0][0
# __________________________________________________________________________________________________
# stage2/block4/bn_3x3dwconv (Bat (None, 4, 4, 116)    464         stage2/block4/3x3dwconv[0][0]
# __________________________________________________________________________________________________
# stage2/block4/1x1conv_2 (Conv2D (None, 4, 4, 116)    13572       stage2/block4/bn_3x3dwconv[0][0]
# __________________________________________________________________________________________________
# stage2/block4/bn_1x1conv_2 (Bat (None, 4, 4, 116)    464         stage2/block4/1x1conv_2[0][0]
# __________________________________________________________________________________________________
# stage2/block4/relu_1x1conv_2 (A (None, 4, 4, 116)    0           stage2/block4/bn_1x1conv_2[0][0]
# __________________________________________________________________________________________________
# stage2/block4/spl/sp0_slice (La (None, 4, 4, 116)    0           stage2/block3/channel_shuffle[0][
# __________________________________________________________________________________________________
# stage2/block4/concat_1 (Concate (None, 4, 4, 232)    0           stage2/block4/relu_1x1conv_2[0][0
#                                                                  stage2/block4/spl/sp0_slice[0][0]
# __________________________________________________________________________________________________
# stage2/block4/channel_shuffle ( (None, 4, 4, 232)    0           stage2/block4/concat_1[0][0]
# __________________________________________________________________________________________________
# stage3/block1/1x1conv_1 (Conv2D (None, 4, 4, 232)    54056       stage2/block4/channel_shuffle[0][
# __________________________________________________________________________________________________
# stage3/block1/bn_1x1conv_1 (Bat (None, 4, 4, 232)    928         stage3/block1/1x1conv_1[0][0]
# __________________________________________________________________________________________________
# stage3/block1/relu_1x1conv_1 (A (None, 4, 4, 232)    0           stage3/block1/bn_1x1conv_1[0][0]
# __________________________________________________________________________________________________
# stage3/block1/3x3dwconv (Depthw (None, 2, 2, 232)    2320        stage3/block1/relu_1x1conv_1[0][0
# __________________________________________________________________________________________________
# stage3/block1/3x3dwconv_2 (Dept (None, 2, 2, 232)    2320        stage2/block4/channel_shuffle[0][
# __________________________________________________________________________________________________
# stage3/block1/bn_3x3dwconv (Bat (None, 2, 2, 232)    928         stage3/block1/3x3dwconv[0][0]
# __________________________________________________________________________________________________
# stage3/block1/bn_3x3dwconv_2 (B (None, 2, 2, 232)    928         stage3/block1/3x3dwconv_2[0][0]
# __________________________________________________________________________________________________
# stage3/block1/1x1conv_2 (Conv2D (None, 2, 2, 232)    54056       stage3/block1/bn_3x3dwconv[0][0]
# __________________________________________________________________________________________________
# stage3/block1/1x1_conv_3 (Conv2 (None, 2, 2, 232)    54056       stage3/block1/bn_3x3dwconv_2[0][0
# __________________________________________________________________________________________________
# stage3/block1/bn_1x1conv_2 (Bat (None, 2, 2, 232)    928         stage3/block1/1x1conv_2[0][0]
# __________________________________________________________________________________________________
# stage3/block1/bn_1x1conv_3 (Bat (None, 2, 2, 232)    928         stage3/block1/1x1_conv_3[0][0]
# __________________________________________________________________________________________________
# stage3/block1/relu_1x1conv_2 (A (None, 2, 2, 232)    0           stage3/block1/bn_1x1conv_2[0][0]
# __________________________________________________________________________________________________
# stage3/block1/relu_1x1conv_3 (A (None, 2, 2, 232)    0           stage3/block1/bn_1x1conv_3[0][0]
# __________________________________________________________________________________________________
# stage3/block1/concat_2 (Concate (None, 2, 2, 464)    0           stage3/block1/relu_1x1conv_2[0][0
#                                                                  stage3/block1/relu_1x1conv_3[0][0
# __________________________________________________________________________________________________
# stage3/block1/channel_shuffle ( (None, 2, 2, 464)    0           stage3/block1/concat_2[0][0]
# __________________________________________________________________________________________________
# stage3/block2/spl/sp1_slice (La (None, 2, 2, 232)    0           stage3/block1/channel_shuffle[0][
# __________________________________________________________________________________________________
# stage3/block2/1x1conv_1 (Conv2D (None, 2, 2, 232)    54056       stage3/block2/spl/sp1_slice[0][0]
# __________________________________________________________________________________________________
# stage3/block2/bn_1x1conv_1 (Bat (None, 2, 2, 232)    928         stage3/block2/1x1conv_1[0][0]
# __________________________________________________________________________________________________
# stage3/block2/relu_1x1conv_1 (A (None, 2, 2, 232)    0           stage3/block2/bn_1x1conv_1[0][0]
# __________________________________________________________________________________________________
# stage3/block2/3x3dwconv (Depthw (None, 2, 2, 232)    2320        stage3/block2/relu_1x1conv_1[0][0
# __________________________________________________________________________________________________
# stage3/block2/bn_3x3dwconv (Bat (None, 2, 2, 232)    928         stage3/block2/3x3dwconv[0][0]
# __________________________________________________________________________________________________
# stage3/block2/1x1conv_2 (Conv2D (None, 2, 2, 232)    54056       stage3/block2/bn_3x3dwconv[0][0]
# __________________________________________________________________________________________________
# stage3/block2/bn_1x1conv_2 (Bat (None, 2, 2, 232)    928         stage3/block2/1x1conv_2[0][0]
# __________________________________________________________________________________________________
# stage3/block2/relu_1x1conv_2 (A (None, 2, 2, 232)    0           stage3/block2/bn_1x1conv_2[0][0]
# __________________________________________________________________________________________________
# stage3/block2/spl/sp0_slice (La (None, 2, 2, 232)    0           stage3/block1/channel_shuffle[0][
# __________________________________________________________________________________________________
# stage3/block2/concat_1 (Concate (None, 2, 2, 464)    0           stage3/block2/relu_1x1conv_2[0][0
#                                                                  stage3/block2/spl/sp0_slice[0][0]
# __________________________________________________________________________________________________
# stage3/block2/channel_shuffle ( (None, 2, 2, 464)    0           stage3/block2/concat_1[0][0]
# __________________________________________________________________________________________________
# stage3/block3/spl/sp1_slice (La (None, 2, 2, 232)    0           stage3/block2/channel_shuffle[0][
# __________________________________________________________________________________________________
# stage3/block3/1x1conv_1 (Conv2D (None, 2, 2, 232)    54056       stage3/block3/spl/sp1_slice[0][0]
# __________________________________________________________________________________________________
# stage3/block3/bn_1x1conv_1 (Bat (None, 2, 2, 232)    928         stage3/block3/1x1conv_1[0][0]
# __________________________________________________________________________________________________
# stage3/block3/relu_1x1conv_1 (A (None, 2, 2, 232)    0           stage3/block3/bn_1x1conv_1[0][0]
# __________________________________________________________________________________________________
# stage3/block3/3x3dwconv (Depthw (None, 2, 2, 232)    2320        stage3/block3/relu_1x1conv_1[0][0
# __________________________________________________________________________________________________
# stage3/block3/bn_3x3dwconv (Bat (None, 2, 2, 232)    928         stage3/block3/3x3dwconv[0][0]
# __________________________________________________________________________________________________
# stage3/block3/1x1conv_2 (Conv2D (None, 2, 2, 232)    54056       stage3/block3/bn_3x3dwconv[0][0]
# __________________________________________________________________________________________________
# stage3/block3/bn_1x1conv_2 (Bat (None, 2, 2, 232)    928         stage3/block3/1x1conv_2[0][0]
# __________________________________________________________________________________________________
# stage3/block3/relu_1x1conv_2 (A (None, 2, 2, 232)    0           stage3/block3/bn_1x1conv_2[0][0]
# __________________________________________________________________________________________________
# stage3/block3/spl/sp0_slice (La (None, 2, 2, 232)    0           stage3/block2/channel_shuffle[0][
# __________________________________________________________________________________________________
# stage3/block3/concat_1 (Concate (None, 2, 2, 464)    0           stage3/block3/relu_1x1conv_2[0][0
#                                                                  stage3/block3/spl/sp0_slice[0][0]
# __________________________________________________________________________________________________
# stage3/block3/channel_shuffle ( (None, 2, 2, 464)    0           stage3/block3/concat_1[0][0]
# __________________________________________________________________________________________________
# stage3/block4/spl/sp1_slice (La (None, 2, 2, 232)    0           stage3/block3/channel_shuffle[0][
# __________________________________________________________________________________________________
# stage3/block4/1x1conv_1 (Conv2D (None, 2, 2, 232)    54056       stage3/block4/spl/sp1_slice[0][0]
# __________________________________________________________________________________________________
# stage3/block4/bn_1x1conv_1 (Bat (None, 2, 2, 232)    928         stage3/block4/1x1conv_1[0][0]
# __________________________________________________________________________________________________
# stage3/block4/relu_1x1conv_1 (A (None, 2, 2, 232)    0           stage3/block4/bn_1x1conv_1[0][0]
# __________________________________________________________________________________________________
# stage3/block4/3x3dwconv (Depthw (None, 2, 2, 232)    2320        stage3/block4/relu_1x1conv_1[0][0
# __________________________________________________________________________________________________
# stage3/block4/bn_3x3dwconv (Bat (None, 2, 2, 232)    928         stage3/block4/3x3dwconv[0][0]
# __________________________________________________________________________________________________
# stage3/block4/1x1conv_2 (Conv2D (None, 2, 2, 232)    54056       stage3/block4/bn_3x3dwconv[0][0]
# __________________________________________________________________________________________________
# stage3/block4/bn_1x1conv_2 (Bat (None, 2, 2, 232)    928         stage3/block4/1x1conv_2[0][0]
# __________________________________________________________________________________________________
# stage3/block4/relu_1x1conv_2 (A (None, 2, 2, 232)    0           stage3/block4/bn_1x1conv_2[0][0]
# __________________________________________________________________________________________________
# stage3/block4/spl/sp0_slice (La (None, 2, 2, 232)    0           stage3/block3/channel_shuffle[0][
# __________________________________________________________________________________________________
# stage3/block4/concat_1 (Concate (None, 2, 2, 464)    0           stage3/block4/relu_1x1conv_2[0][0
#                                                                  stage3/block4/spl/sp0_slice[0][0]
# __________________________________________________________________________________________________
# stage3/block4/channel_shuffle ( (None, 2, 2, 464)    0           stage3/block4/concat_1[0][0]
# __________________________________________________________________________________________________
# stage3/block5/spl/sp1_slice (La (None, 2, 2, 232)    0           stage3/block4/channel_shuffle[0][
# __________________________________________________________________________________________________
# stage3/block5/1x1conv_1 (Conv2D (None, 2, 2, 232)    54056       stage3/block5/spl/sp1_slice[0][0]
# __________________________________________________________________________________________________
# stage3/block5/bn_1x1conv_1 (Bat (None, 2, 2, 232)    928         stage3/block5/1x1conv_1[0][0]
# __________________________________________________________________________________________________
# stage3/block5/relu_1x1conv_1 (A (None, 2, 2, 232)    0           stage3/block5/bn_1x1conv_1[0][0]
# __________________________________________________________________________________________________
# stage3/block5/3x3dwconv (Depthw (None, 2, 2, 232)    2320        stage3/block5/relu_1x1conv_1[0][0
# __________________________________________________________________________________________________
# stage3/block5/bn_3x3dwconv (Bat (None, 2, 2, 232)    928         stage3/block5/3x3dwconv[0][0]
# __________________________________________________________________________________________________
# stage3/block5/1x1conv_2 (Conv2D (None, 2, 2, 232)    54056       stage3/block5/bn_3x3dwconv[0][0]
# __________________________________________________________________________________________________
# stage3/block5/bn_1x1conv_2 (Bat (None, 2, 2, 232)    928         stage3/block5/1x1conv_2[0][0]
# __________________________________________________________________________________________________
# stage3/block5/relu_1x1conv_2 (A (None, 2, 2, 232)    0           stage3/block5/bn_1x1conv_2[0][0]
# __________________________________________________________________________________________________
# stage3/block5/spl/sp0_slice (La (None, 2, 2, 232)    0           stage3/block4/channel_shuffle[0][
# __________________________________________________________________________________________________
# stage3/block5/concat_1 (Concate (None, 2, 2, 464)    0           stage3/block5/relu_1x1conv_2[0][0
#                                                                  stage3/block5/spl/sp0_slice[0][0]
# __________________________________________________________________________________________________
# stage3/block5/channel_shuffle ( (None, 2, 2, 464)    0           stage3/block5/concat_1[0][0]
# __________________________________________________________________________________________________
# stage3/block6/spl/sp1_slice (La (None, 2, 2, 232)    0           stage3/block5/channel_shuffle[0][
# __________________________________________________________________________________________________
# stage3/block6/1x1conv_1 (Conv2D (None, 2, 2, 232)    54056       stage3/block6/spl/sp1_slice[0][0]
# __________________________________________________________________________________________________
# stage3/block6/bn_1x1conv_1 (Bat (None, 2, 2, 232)    928         stage3/block6/1x1conv_1[0][0]
# __________________________________________________________________________________________________
# stage3/
1x1conv_1[0][0]
# __________________________________________________________________________________________________
# stage4/block1/relu_1x1conv_1 (A (None, 2, 2, 464)    0           stage4/block1/bn_1x1conv_1[0][0]
# __________________________________________________________________________________________________
# stage4/block1/3x3dwconv (Depthw (None, 1, 1, 464)    4640        stage4/block1/relu_1x1conv_1[0][0
# __________________________________________________________________________________________________
# stage4/block1/3x3dwconv_2 (Dept (None, 1, 1, 464)    4640        stage3/block8/channel_shuffle[0][
# __________________________________________________________________________________________________
# stage4/block1/bn_3x3dwconv (Bat (None, 1, 1, 464)    1856        stage4/block1/3x3dwconv[0][0]
# __________________________________________________________________________________________________
# stage4/block1/bn_3x3dwconv_2 (B (None, 1, 1, 464)    1856        stage4/block1/3x3dwconv_2[0][0]
# __________________________________________________________________________________________________
# stage4/block1/1x1conv_2 (Conv2D (None, 1, 1, 464)    215760      stage4/block1/bn_3x3dwconv[0][0]
# __________________________________________________________________________________________________
# stage4/block1/1x1_conv_3 (Conv2 (None, 1, 1, 464)    215760      stage4/block1/bn_3x3dwconv_2[0][0
# __________________________________________________________________________________________________
# stage4/block1/bn_1x1conv_2 (Bat (None, 1, 1, 464)    1856        stage4/block1/1x1conv_2[0][0]
# __________________________________________________________________________________________________
# stage4/block1/bn_1x1conv_3 (Bat (None, 1, 1, 464)    1856        stage4/block1/1x1_conv_3[0][0]
# __________________________________________________________________________________________________
# stage4/block1/relu_1x1conv_2 (A (None, 1, 1, 464)    0           stage4/block1/bn_1x1conv_2[0][0]
# __________________________________________________________________________________________________
# stage4/block1/relu_1x1conv_3 (A (None, 1, 1, 464)    0           stage4/block1/bn_1x1conv_3[0][0]
# __________________________________________________________________________________________________
# stage4/block1/concat_2 (Concate (None, 1, 1, 928)    0           stage4/block1/relu_1x1conv_2[0][0
#                                                                  stage4/block1/relu_1x1conv_3[0][0
# __________________________________________________________________________________________________
# stage4/block1/channel_shuffle ( (None, 1, 1, 928)    0           stage4/block1/concat_2[0][0]
# __________________________________________________________________________________________________
# stage4/block2/spl/sp1_slice (La (None, 1, 1, 464)    0           stage4/block1/channel_shuffle[0][
# __________________________________________________________________________________________________
# stage4/block2/1x1conv_1 (Conv2D (None, 1, 1, 464)    215760      stage4/block2/spl/sp1_slice[0][0]
# __________________________________________________________________________________________________
# stage4/block2/bn_1x1conv_1 (Bat (None, 1, 1, 464)    1856        stage4/block2/1x1conv_1[0][0]
# __________________________________________________________________________________________________
# stage4/block2/relu_1x1conv_1 (A (None, 1, 1, 464)    0           stage4/block2/bn_1x1conv_1[0][0]
# __________________________________________________________________________________________________
# stage4/block2/3x3dwconv (Depthw (None, 1, 1, 464)    4640        stage4/block2/relu_1x1conv_1[0][0
# __________________________________________________________________________________________________
# stage4/block2/bn_3x3dwconv (Bat (None, 1, 1, 464)    1856        stage4/block2/3x3dwconv[0][0]
# __________________________________________________________________________________________________
# stage4/block2/1x1conv_2 (Conv2D (None, 1, 1, 464)    215760      stage4/block2/bn_3x3dwconv[0][0]
# __________________________________________________________________________________________________
# stage4/block2/bn_1x1conv_2 (Bat (None, 1, 1, 464)    1856        stage4/block2/1x1conv_2[0][0]
# __________________________________________________________________________________________________
# stage4/block2/relu_1x1conv_2 (A (None, 1, 1, 464)    0           stage4/block2/bn_1x1conv_2[0][0]
# __________________________________________________________________________________________________
# stage4/block2/spl/sp0_slice (La (None, 1, 1, 464)    0           stage4/block1/channel_shuffle[0][
# __________________________________________________________________________________________________
# stage4/block2/concat_1 (Concate (None, 1, 1, 928)    0           stage4/block2/relu_1x1conv_2[0][0
#                                                                  stage4/block2/spl/sp0_slice[0][0]
# __________________________________________________________________________________________________
# stage4/block2/channel_shuffle ( (None, 1, 1, 928)    0           stage4/block2/concat_1[0][0]
# __________________________________________________________________________________________________
# stage4/block3/spl/sp1_slice (La (None, 1, 1, 464)    0           stage4/block2/channel_shuffle[0][
# __________________________________________________________________________________________________
# stage4/block3/1x1conv_1 (Conv2D (None, 1, 1, 464)    215760      stage4/block3/spl/sp1_slice[0][0]
# __________________________________________________________________________________________________
# stage4/block3/bn_1x1conv_1 (Bat (None, 1, 1, 464)    1856        stage4/block3/1x1conv_1[0][0]
# __________________________________________________________________________________________________
# stage4/block3/relu_1x1conv_1 (A (None, 1, 1, 464)    0           stage4/block3/bn_1x1conv_1[0][0]
# __________________________________________________________________________________________________
# stage4/block3/3x3dwconv (Depthw (None, 1, 1, 464)    4640        stage4/block3/relu_1x1conv_1[0][0
# __________________________________________________________________________________________________
# stage4/block3/bn_3x3dwconv (Bat (None, 1, 1, 464)    1856        stage4/block3/3x3dwconv[0][0]
# __________________________________________________________________________________________________
# stage4/block3/1x1conv_2 (Conv2D (None, 1, 1, 464)    215760      stage4/block3/bn_3x3dwconv[0][0]
# __________________________________________________________________________________________________
# stage4/block3/bn_1x1conv_2 (Bat (None, 1, 1, 464)    1856        stage4/block3/1x1conv_2[0][0]
# __________________________________________________________________________________________________
# stage4/block3/relu_1x1conv_2 (A (None, 1, 1, 464)    0           stage4/block3/bn_1x1conv_2[0][0]
# __________________________________________________________________________________________________
# stage4/block3/spl/sp0_slice (La (None, 1, 1, 464)    0           stage4/block2/channel_shuffle[0][
# __________________________________________________________________________________________________
# stage4/block3/concat_1 (Concate (None, 1, 1, 928)    0           stage4/block3/relu_1x1conv_2[0][0
#                                                                  stage4/block3/spl/sp0_slice[0][0]
# __________________________________________________________________________________________________
# stage4/block3/channel_shuffle ( (None, 1, 1, 928)    0           stage4/block3/concat_1[0][0]
# __________________________________________________________________________________________________
# stage4/block4/spl/sp1_slice (La (None, 1, 1, 464)    0           stage4/block3/channel_shuffle[0][
# __________________________________________________________________________________________________
# stage4/block4/1x1conv_1 (Conv2D (None, 1, 1, 464)    215760      stage4/block4/spl/sp1_slice[0][0]
# __________________________________________________________________________________________________
# stage4/block4/bn_1x1conv_1 (Bat (None, 1, 1, 464)    1856        stage4/block4/1x1conv_1[0][0]
# __________________________________________________________________________________________________
# stage4/block4/relu_1x1conv_1 (A (None, 1, 1, 464)    0           stage4/block4/bn_1x1conv_1[0][0]
# __________________________________________________________________________________________________
# stage4/block4/3x3dwconv (Depthw (None, 1, 1, 464)    4640        stage4/block4/relu_1x1conv_1[0][0
# __________________________________________________________________________________________________
# stage4/block4/bn_3x3dwconv (Bat (None, 1, 1, 464)    1856        stage4/block4/3x3dwconv[0][0]
# __________________________________________________________________________________________________
# stage4/block4/1x1conv_2 (Conv2D (None, 1, 1, 464)    215760      stage4/block4/bn_3x3dwconv[0][0]
# __________________________________________________________________________________________________
# stage4/block4/bn_1x1conv_2 (Bat (None, 1, 1, 464)    1856        stage4/block4/1x1conv_2[0][0]
# __________________________________________________________________________________________________
# stage4/block4/relu_1x1conv_2 (A (None, 1, 1, 464)    0           stage4/block4/bn_1x1conv_2[0][0]
# __________________________________________________________________________________________________
# stage4/block4/spl/sp0_slice (La (None, 1, 1, 464)    0           stage4/block3/channel_shuffle[0][
# __________________________________________________________________________________________________
# stage4/block4/concat_1 (Concate (None, 1, 1, 928)    0           stage4/block4/relu_1x1conv_2[0][0
#                                                                  stage4/block4/spl/sp0_slice[0][0]
# __________________________________________________________________________________________________
# stage4/block4/channel_shuffle ( (None, 1, 1, 928)    0           stage4/block4/concat_1[0][0]
# __________________________________________________________________________________________________
# 1x1conv5_out (Conv2D)           (None, 1, 1, 1024)   951296      stage4/block4/channel_shuffle[0][
# __________________________________________________________________________________________________
# global_max_pool (GlobalMaxPooli (None, 1024)         0           1x1conv5_out[0][0]
# __________________________________________________________________________________________________
# fc (Dense)                      (None, 10)           10250       global_max_pool[0][0]
# __________________________________________________________________________________________________
# softmax (Activation)            (None, 10)           0           fc[0][0]
# ==================================================================================================
# Total params: 4,028,990
# Trainable params: 4,000,870
# Non-trainable params: 28,120
# __________________________________________________________________________________________________

# %%
model.fit_generator(train_datagen.flow(x_train,y_train,batch_size=64),
                    steps_per_epoch = x_train.shape[0] / 64,
                    validation_data = (x_val,y_val),
                    validation_steps = x_val.shape[0] / 64,
                    epochs = 100,
                    callbacks=[LR_function])
# Out:
# Epoch 1/100
# 586/585 [==============================] - 46s 79ms/step - loss: 1.9102 - acc: 0.3007 - val_loss: 1.7362 - val_acc: 0.3815
# Epoch 2/100
# 586/585 [==============================] - 37s 63ms/step - loss: 1.6314 - acc: 0.4011 - val_loss: 1.5068 - val_acc: 0.4552
